# %%
with open('log18','r',encoding='utf8') as f:
    data =[]
    for i in f:
        data.append(i)

# %%
text = ''.join(data)

# %%
k = text.split('--------------------------------')

# %%
for i in k:
    q = i.split('\n')
    if eval(q[-2])['f']<=0.6:
        print(i)
# Out:
# txt: 1.严格消毒，防止感染因耳郭在外，表面凸凹不平，结构特殊，针刺前必须严格消毒，有伤面和炎症部位禁针，针刺后如针孔发红、肿胀应及时涂2.5%碘酒，防止化脓性软骨膜炎的发生。2.对扭伤和有运动障碍者进针后宜适当活动，有利于提高疗效。3.对习惯性流产的孕妇慎用针。4.对心血管疾病患者患有严重器质性病变和伴有高度贫血者不宜针刺，对严重心脏病、高血压患者不宜行强刺激。5.晕针的防治耳针治疗时应注意防止发生晕针，如发生应及时拔针、平卧，对症处理。ans: 针 刺 前 必 须 严 格 消 毒 ， 有 伤 面 和 炎 症 部 位 禁 针 ， 针 刺 后 如 针 孔 发 红 、 肿 胀 应 及 时 涂 2 . 5 % 碘 酒 ， 防 止 化 脓 性 软 骨 膜 炎 的 发 生 。
# -
# tgt:  针 刺 前 如 何 对 耳 郭 进 行 消 毒 ？
# prd:  针 刺 前 应 注 意 什 么 ？
# {'f': 0.36363635880165296, 'p': 0.4444444444444444, 'r': 0.3076923076923077}
#
#
# txt: 肺气虚证：肺气虚，卫外不固，属外感表虚。症见自汗，畏风，咳喘无力，气少不足以息，动则益甚，语声低微，面色?白，神疲体倦。肺气虚不能宣发卫气于肌表，腠理不密，卫表不固，故见自汗，畏风；肺气被耗，则宗气不足，呼吸功能减弱，因而咳喘无力，气少不足以息，且动则耗气，所以动则喘息益甚。脾肺气虚证：脾肺两脏气虚，卫气不能固秘，肌表疏松，经常自汗，易被外邪侵袭，属内伤表虚。症见恶风，自汗，气短而喘，痰多稀白，食欲不振，腹胀便溏，声低懒言，疲倦乏力。久咳不止，肺气受损，故咳嗽气短而喘；脾气虚，运化失健，可见食欲不振，腹胀不舒；湿邪下注，则大便溏泻；气虚功能活动减弱，故声低懒言，疲倦乏力。
# ...
